# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Prashant\Downloads\Online_Retail_2009_2010.xlsx")

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#       InvoiceDate  Price  Customer ID         Country
# 0  12/1/2009 7:45   6.95      13085.0  United Kingdom
# 1  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 2  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 3  12/1/2009 7:45   2.10      13085.0  United Kingdom
# 4  12/1/2009 7:45   1.25      13085.0  United Kingdom

# %%
df.dtypes
# Out:
# Invoice         object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# Price          float64
# Customer ID    float64
# Country         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
df = df[df['Quantity']>0]
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
df = df[df['Price']>0]
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
df = df.reset_index(drop=True)

# %%
print("\nDataset shape after cleaning:",df.shape)
# Out:
# Dataset shape after cleaning: (407664, 8)

# %%
df.to_csv("cleaned_attendance_data.csv", index=False)

# %%
df.to_csv("Online_Retail_Cleaned.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Prashant\\.jupyter'

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Prashant\.jupyter\Online_Retail_Cleaned.csv")
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 407659   538171     22271                 FELTCRAFT DOLL ROSIE         2
# 407660   538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 407661   538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 407662   538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 407663   538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Prashant\.jupyter\Online_Retail_Cleaned.csv")

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df['TotalAmount'] = df['Quantity'] * df['Price']
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  TotalAmount
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom         83.4
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom         81.0
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom         81.0
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom        100.8
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom         30.0

# %%
snapshot_date = df['InvoiceDate'].max() + pd.Timedelta(days=1)

# %%
rfm = df.groupby('Customer ID').agg({
    'InvoiceDate' : lambda x: (snapshot_date - x.max()).days,  
    'Invoice' : 'nunique',
    'TotalAmount' : 'sum'
})

rfm.rename(columns={
    'InvoiceDate' : 'Recency',
    'Invoice' : 'Frequency',
    'TotalAmount' : 'Monetary'
    }, inplace=True)

rfm.head()
# Out:
#              Recency  Frequency  Monetary
# Customer ID
# 12346.0          165         11    372.86
# 12347.0            3          2   1323.32
# 12348.0           74          1    222.16
# 12349.0           43          3   2671.14
# 12351.0           11          1    300.93

# %%
rfm.dtypes
# Out:
# Recency        int64
# Frequency      int64
# Monetary     float64
# dtype: object

# %%
rfm['R_Score'] = pd.qcut(rfm['Recency'], 5, labels=[5,4,3,2,1])
rfm['F_Score'] = pd.qcut(rfm['Frequency'].rank(method='first'), 5, labels=[1,2,3,4,5])
rfm['M_Score'] = pd.qcut(rfm['Monetary'], 5, labels=[1,2,3,4,5])

rfm.head()
# Out:
#              Recency  Frequency  Monetary R_Score F_Score M_Score
# Customer ID
# 12346.0          165         11    372.86       2       5       2
# 12347.0            3          2   1323.32       5       2       4
# 12348.0           74          1    222.16       2       1       1
# 12349.0           43          3   2671.14       3       3       5
# 12351.0           11          1    300.93       5       1       2

# %%
rfm['RFM_Score'] = rfm['R_Score'].astype(str) + \
                   rfm['F_Score'].astype(str) + \
                   rfm['M_Score'].astype(str)

rfm.head()
# Out:
#              Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score
# Customer ID
# 12346.0          165         11    372.86       2       5       2       252
# 12347.0            3          2   1323.32       5       2       4       524
# 12348.0           74          1    222.16       2       1       1       211
# 12349.0           43          3   2671.14       3       3       5       335
# 12351.0           11          1    300.93       5       1       2       512

# %%
def segment_customer(row):
    if row['R_Score'] >= 4 and row['F_Score'] >= 4:
        return 'Champions'

    elif row['F_Score'] >= 4:
        return 'Loyalists'

    elif row['R_Score'] <= 2 and row['F_Score'] <= 2:
        return 'Hibernating'

    else:
        return 'Potential'

rfm['Segment'] = rfm.apply(segment_customer, axis=1)

# %%
rfm.head()
# Out:
#              Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score  \
# Customer ID
# 12346.0          165         11    372.86       2       5       2       252
# 12347.0            3          2   1323.32       5       2       4       524
# 12348.0           74          1    222.16       2       1       1       211
# 12349.0           43          3   2671.14       3       3       5       335
# 12351.0           11          1    300.93       5       1       2       512
#
#                  Segment
# Customer ID
# 12346.0        Loyalists
# 12347.0        Potential
# 12348.0      Hibernating
# 12349.0        Potential
# 12351.0        Potential

# %%
rfm['Segment'].value_counts()
# Out:
# Segment
# Potential      1572
# Champions      1105
# Hibernating    1015
# Loyalists       620
# Name: count, dtype: int64

# %%
rfm.to_csv("rfm_data.csv", index=False)

# %%
import pandas as pd
df = pd.read_csv(r"rfm_data.csv")
df
# Out:
#       Recency  Frequency  Monetary  R_Score  F_Score  M_Score  RFM_Score  \
# 0         165         11    372.86        2        5        2        252
# 1           3          2   1323.32        5        2        4        524
# 2          74          1    222.16        2        1        1        211
# 3          43          3   2671.14        3        3        5        335
# 4          11          1    300.93        5        1        2        512
# ...       ...        ...       ...      ...      ...      ...        ...
# 4307       18          6    641.77        4        5        3        453
# 4308       67          1    461.68        3        2        2        322
# 4309      296          1    427.00        1        2        2        122
# 4310      112          2   1296.43        2        3        4        234
# 4311       18          4   2345.71        4        4        5        445
#
#           Segment
# 0       Loyalists
# 1       Potential
# 2     Hibernating
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Prashant\\.jupyter'

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 1.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 0.8/2.8 MB 1.2 MB/s eta 0:00:02
#    -------------- ------------------------- 1.0/2.8 MB 1.2 MB/s eta 0:00:02
#    ------------------ --------------------- 1.3/2.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.8 MB 1.2 MB/s eta 0:00:02
#    -------------------------- ------------- 1.8/2.8 MB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 951.0 kB/s eta 0:00:01
# ...

# %%
import psycopg2

conn = psycopg2.connect(
    dbname = "customer_behaviour",
    user = "postgres",
    password = "Pass123",
    host = "localhost",
    port = "5432"
)

cur = conn.cursor()


cur.close()
conn.close()
